# %%
import polars as pl
import numpy as np
from pathlib import Path
from collections import defaultdict
from datetime import datetime
from redis_om import JsonModel, HashModel
from pydantic import validator, BaseModel, root_validator, ByteSize
from io import BytesIO

# %%
data_dir = Path("data")
filenames = (data_dir/"byType").glob("*.csv")

# %%
dt = []
for file in filenames:
    dt.append(pl.read_csv(file))

# %%
dt[0]
# Out:
# shape: (49, 10)
# ┌─────┬─────────┬───────────────────┬───────────┬─────┬─────────┬────────────┬────────┬────────────┐
# │     ┆ country ┆ equipment_type    ┆ destroyed ┆ ... ┆ damaged ┆ type_total ┆ row_id ┆ Date       │
# │ --- ┆ ---     ┆ ---               ┆ ---       ┆     ┆ ---     ┆ ---        ┆ ---    ┆ ---        │
# │ i64 ┆ str     ┆ str               ┆ i64       ┆     ┆ i64     ┆ i64        ┆ i64    ┆ str        │
# ╞═════╪═════════╪═══════════════════╪═══════════╪═════╪═════════╪════════════╪════════╪════════════╡
# │ 1   ┆ Russia  ┆ All Types         ┆ 3304      ┆ ... ┆ 116     ┆ 5169       ┆ 1      ┆ 2022-08-12 │
# │ 2   ┆ Russia  ┆ Tanks             ┆ 573       ┆ ... ┆ 36      ┆ 940        ┆ 2      ┆ 2022-08-12 │
# │ 3   ┆ Russia  ┆ Armoured Fighting ┆ 355       ┆ ... ┆ 6       ┆ 534        ┆ 3      ┆ 2022-08-12 │
# │     ┆         ┆ Vehicles          ┆           ┆     ┆         ┆            ┆        ┆            │
# │ 4   ┆ Russia  ┆ Infantry Fighting ┆ 671       ┆ ... ┆ 21      ┆ 1024       ┆ 4      ┆ 2022-08-12 │
# │     ┆         ┆ Vehicles          ┆           ┆     ┆         ┆            ┆        ┆            │
# │ ... ┆ ...     ┆ ...               ┆ ...       ┆ ... ┆ ...     ┆ ...        ┆ ...    ┆ ...        │
# │ 46  ┆ Ukraine ┆ Helicopters       ┆ 8         ┆ ... ┆ 0       ┆ 11         ┆ 21     ┆ 2022-08-12 │
# │ 47  ┆ Ukraine ┆ Unmanned Aerial   ┆ 23        ┆ ... ┆ 0       ┆ 31         ┆ 22     ┆ 2022-08-12 │
# │     ┆         ┆ Vehicles          ┆           ┆     ┆         ┆            ┆        ┆            │
# │ 48  ┆ Ukraine ┆ Naval Ships       ┆ 6         ┆ ... ┆ 0       ┆ 19         ┆ 23     ┆ 2022-08-12 │
# │ 49  ┆ Ukraine ┆ Trucks, Vehicles  ┆ 181       ┆ ... ┆ 6       ┆ 342        ┆ 24     ┆ 2022-08-12 │
# │     ┆         ┆ and Jeeps         ┆           ┆     ┆         ┆            ┆        ┆            │
# └─────┴─────────┴───────────────────┴───────────┴─────┴─────────┴────────────┴────────┴────────────┘

# %%
stacked_russia = defaultdict(list)
stacked_ukraine = defaultdict(list)
for day in dt:
    date = datetime.strptime(day["Date"][0],'%Y-%m-%d')
    ru = day.filter(pl.col("country")=="Russia").select(["equipment_type", "type_total"]).to_dict(as_series=False)
    for equipment_type, number in zip(ru["equipment_type"], ru["type_total"]):
        stacked_russia[equipment_type].append((date, number))
    ukr = day.filter(pl.col("country")=="Ukraine").select(["equipment_type", "type_total"]).to_dict(as_series=False)
    for equipment_type, number in zip(ukr["equipment_type"], ukr["type_total"]):
        stacked_ukraine[equipment_type].append((date, number))

# %%
stacked_russia = dict(stacked_russia)
stacked_ukraine = dict(stacked_ukraine)

# %%
russia = []
for day in dt:
    date = day["Date"][0].replace("-","")
    ru = day.filter(pl.col("country")=="Russia").select(["equipment_type", "type_total"]).to_dict(as_series=False)
    russia.append({
        "date": date,
        **{eqp.replace(" ", "").replace("-", "").replace("\n","").replace(",",""):number for eqp, number in zip(ru["equipment_type"], ru["type_total"]) if eqp!="All Types"}
    })
russia
# Out:
# [{'date': '20220812',
#   'Tanks': 940,
#   'ArmouredFightingVehicles': 534,
#   'InfantryFightingVehicles': 1024,
#   'ArmouredPersonnelCarriers': 142,
#   'MineResistantAmbushProtected': 32,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 108,
#   'EngineeringVehiclesAndEquipment': 179,
#   'SelfPropelledAntiTankMissileSystems': 22,
#   'HeavyMortars': 14,
#   'TowedArtillery': 75,
#   'SelfPropelledArtillery': 152,
#   'MultipleRocketLaunchers': 93,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 17,
#   'SurfaceToAirMissileSystems': 68,
#   'Radars': 13,
#   'JammersAndDeceptionSystems': 12,
#   'Aircraft': 50,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 105,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1402},
#  {'date': '20220225',
#   'Tanks': 2,
#   'ArmouredFightingVehicles': 7,
#   'InfantryFightingVehicles': 4,
#   'MineresistantAmbushProtected': 1,
#   'InfantryMobilityVehicles': 5,
#   'EngineeringVehicles': 3,
#   'Mortars': 1,
#   'Artillery': 4,
#   'MultipleRocketLaunchers': 4,
#   'SurfaceToAirMissileSystems': 2,
#   'Aircraft': 3,
#   'Helicopters': 2,
#   'TrucksVehiclesandJeeps': 19},
#  {'date': '20221030',
#   'Tanks': 1419,
#   'ArmouredFightingVehicles': 683,
#   'InfantryFightingVehicles': 1618,
#   'ArmouredPersonnelCarriers': 250,
#   'MineResistantAmbushProtected': 41,
#   'InfantryMobilityVehicles': 163,
#   'CommandPostsAndCommunicationsStations': 181,
#   'EngineeringVehiclesAndEquipment': 235,
#   'SelfPropelledAntiTankMissileSystems': 28,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 74,
#   'TowedArtillery': 123,
#   'SelfPropelledArtillery': 256,
#   'MultipleRocketLaunchers': 148,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 75,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 17,
#   'Aircraft': 63,
#   'Helicopters': 54,
#   'UnmannedAerialVehicles': 141,
#   'NavalShips': 13,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1894},
#  {'date': '20221107',
#   'Tanks': 1445,
#   'ArmouredFightingVehicles': 684,
#   'InfantryFightingVehicles': 1660,
#   'ArmouredPersonnelCarriers': 254,
#   'MineResistantAmbushProtected': 42,
#   'InfantryMobilityVehicles': 163,
#   'CommandPostsAndCommunicationsStations': 187,
#   'EngineeringVehiclesAndEquipment': 241,
#   'SelfPropelledAntiTankMissileSystems': 28,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 75,
#   'TowedArtillery': 123,
#   'SelfPropelledArtillery': 257,
#   'MultipleRocketLaunchers': 147,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 21,
#   'SurfaceToAirMissileSystems': 75,
#   'Radars': 18,
#   'JammersAndDeceptionSystems': 18,
#   'Aircraft': 63,
#   'Helicopters': 57,
#   'UnmannedAerialVehicles': 141,
#   'NavalShips': 12,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1915},
#  {'date': '20220915',
#   'Tanks': 1130,
#   'ArmouredFightingVehicles': 583,
#   'InfantryFightingVehicles': 1264,
#   'ArmouredPersonnelCarriers': 164,
#   'MineResistantAmbushProtected': 33,
#   'InfantryMobilityVehicles': 127,
#   'CommandPostsAndCommunicationsStations': 142,
#   'EngineeringVehiclesAndEquipment': 203,
#   'SelfPropelledAntiTankMissileSystems': 25,
#   'HeavyMortars': 18,
#   'ArtillerySupportVehiclesAndEquipment': 59,
#   'TowedArtillery': 90,
#   'SelfPropelledArtillery': 202,
#   'MultipleRocketLaunchers': 109,
#   'AntiAircraftGuns': 10,
#   'SelfPropelledAntiAircraftGuns': 18,
#   'SurfaceToAirMissileSystems': 72,
#   'Radars': 15,
#   'JammersAndDeceptionSystems': 15,
#   'Aircraft': 56,
#   'Helicopters': 48,
#   'UnmannedAerialVehicles': 127,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1571},
#  {'date': '20220902',
#   'Tanks': 998,
#   'ArmouredFightingVehicles': 514,
#   'InfantryFightingVehicles': 1077,
#   'ArmouredPersonnelCarriers': 145,
#   'MineResistantAmbushProtected': 30,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 113,
#   'EngineeringVehiclesAndEquipment': 185,
#   'SelfPropelledAntiTankMissileSystems': 23,
#   'HeavyMortars': 16,
#   'ArtillerySupportVehiclesAndEquipment': 53,
#   'TowedArtillery': 78,
#   'SelfPropelledArtillery': 165,
#   'MultipleRocketLaunchers': 90,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 17,
#   'SurfaceToAirMissileSystems': 67,
#   'Radars': 14,
#   'JammersAndDeceptionSystems': 13,
#   'Aircraft': 52,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 122,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1455},
#  {'date': '20220624',
#   'Tanks': 770,
#   'ArmouredFightingVehicles': 435,
#   'InfantryFightingVehicles': 873,
#   'ArmouredPersonnelCarriers': 117,
#   'MineResistantAmbushProtected': 27,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 85,
#   'EngineeringVehiclesAndEquipment': 166,
#   'SelfPropelledAntiTankMissileSystems': 21,
#   'HeavyMortars': 14,
#   'TowedArtillery': 65,
#   'SelfPropelledArtillery': 124,
#   'MultipleRocketLaunchers': 79,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 10,
#   'Aircraft': 35,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 88,
#   'NavalShips': 10,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1184},
#  {'date': '20221118',
#   'Tanks': 1499,
#   'ArmouredFightingVehicles': 715,
#   'InfantryFightingVehicles': 1745,
#   'ArmouredPersonnelCarriers': 269,
#   'MineResistantAmbushProtected': 44,
#   'InfantryMobilityVehicles': 166,
#   'CommandPostsAndCommunicationsStations': 193,
#   'EngineeringVehiclesAndEquipment': 245,
#   'SelfPropelledAntiTankMissileSystems': 29,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 82,
#   'TowedArtillery': 139,
#   'SelfPropelledArtillery': 288,
#   'MultipleRocketLaunchers': 154,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 22,
#   'SurfaceToAirMissileSystems': 77,
#   'Radars': 21,
#   'JammersAndDeceptionSystems': 21,
#   'Aircraft': 63,
#   'Helicopters': 71,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 145,
#   'NavalShips': 12,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1984},
#  {'date': '20220508',
#   'Tanks': 633,
#   'ArmouredFightingVehicles': 342,
#   'InfantryFightingVehicles': 694,
#   'ArmouredPersonnelCarriers': 108,
#   'MineResistantAmbushProtected': 25,
#   'InfantryMobilityVehicles': 103,
#   'CommandPostsAndCommunicationsStations': 73,
#   'EngineeringVehiclesAndEquipment': 129,
#   'SelfPropelledAntiTankMissileSystems': 14,
#   'HeavyMortars': 13,
#   'TowedArtillery': 59,
#   'SelfPropelledArtillery': 105,
#   'MultipleRocketLaunchers': 62,
#   'AntiAircraftGuns': 6,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 58,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 8,
#   'Aircraft': 26,
#   'Helicopters': 41,
#   'UnmannedAerialVehicles': 54,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 919},
#  {'date': '20220724',
#   'Tanks': 885,
#   'ArmouredFightingVehicles': 505,
#   'InfantryFightingVehicles': 965,
#   'ArmouredPersonnelCarriers': 130,
#   'MineResistantAmbushProtected': 30,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 96,
#   'EngineeringVehiclesAndEquipment': 174,
#   'SelfPropelledAntiTankMissileSystems': 21,
#   'HeavyMortars': 14,
#   'TowedArtillery': 72,
#   'SelfPropelledArtillery': 145,
#   'MultipleRocketLaunchers': 93,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 67,
#   'Radars': 12,
#   'JammersAndDeceptionSystems': 10,
#   'Aircraft': 38,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 99,
#   'NavalShips': 11,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1262},
#  {'date': '20220501',
#   'Tanks': 606,
#   'ArmouredFightingVehicles': 322,
#   'InfantryFightingVehicles': 651,
#   'ArmouredPersonnelCarriers': 103,
#   'MineResistantAmbushProtected': 25,
#   'InfantryMobilityVehicles': 101,
#   'CommandPostsAndCommunicationsStations': 71,
#   'EngineeringVehiclesAndEquipment': 121,
#   'HeavyMortars': 12,
#   'TowedArtillery': 59,
#   'SelfPropelledArtillery': 102,
#   'MultipleRocketLaunchers': 63,
#   'AntiAircraftGuns': 4,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 54,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 8,
#   'Aircraft': 26,
#   'Helicopters': 39,
#   'UnmannedAerialVehicles': 49,
#   'NavalShips': 4,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 878},
#  {'date': '20220925',
#   'Tanks': 1192,
#   'ArmouredFightingVehicles': 614,
#   'InfantryFightingVehicles': 1315,
#   'ArmouredPersonnelCarriers': 166,
#   'MineResistantAmbushProtected': 35,
#   'InfantryMobilityVehicles': 129,
#   'CommandPostsAndCommunicationsStations': 156,
#   'EngineeringVehiclesAndEquipment': 208,
#   'SelfPropelledAntiTankMissileSystems': 25,
#   'HeavyMortars': 21,
#   'ArtillerySupportVehiclesAndEquipment': 61,
#   'TowedArtillery': 95,
#   'SelfPropelledArtillery': 211,
#   'MultipleRocketLaunchers': 109,
#   'AntiAircraftGuns': 10,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 72,
#   'Radars': 15,
#   'JammersAndDeceptionSystems': 15,
#   'Aircraft': 58,
#   'Helicopters': 50,
#   'UnmannedAerialVehicles': 131,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1675},
#  {'date': '20221211',
#   'Tanks': 1566,
#   'ArmouredFightingVehicles': 739,
#   'InfantryFightingVehicles': 1837,
#   'ArmouredPersonnelCarriers': 278,
#   'MineResistantAmbushProtected': 44,
#   'InfantryMobilityVehicles': 175,
#   'CommandPostsAndCommunicationsStations': 206,
#   'EngineeringVehiclesAndEquipment': 252,
#   'SelfPropelledAntiTankMissileSystems': 30,
#   'ArtillerySupportVehiclesAndEquipment': 87,
#   'TowedArtillery': 149,
#   'SelfPropelledArtillery': 299,
#   'MultipleRocketLaunchers': 159,
#   'AntiAircraftGuns': 16,
#   'SelfPropelledAntiAircraftGuns': 22,
#   'SurfaceToAirMissileSystems': 77,
#   'Radars': 21,
#   'JammersAndDeceptionSystems': 22,
#   'Aircraft': 67,
#   'Helicopters': 72,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 149,
#   'NavalShips': 12,
#   'TrucksVehiclesandJeeps': 2114},
#  {'date': '20220621',
#   'Tanks': 770,
#   'ArmouredFightingVehicles': 435,
#   'InfantryFightingVehicles': 873,
#   'ArmouredPersonnelCarriers': 117,
#   'MineResistantAmbushProtected': 27,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 85,
#   'EngineeringVehiclesAndEquipment': 166,
#   'SelfPropelledAntiTankMissileSystems': 21,
#   'HeavyMortars': 14,
#   'TowedArtillery': 65,
#   'SelfPropelledArtillery': 124,
#   'MultipleRocketLaunchers': 79,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 10,
#   'Aircraft': 35,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 88,
#   'NavalShips': 10,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1184},
#  {'date': '20220226',
#   'Tanks': 7,
#   'ArmouredFightingVehicles': 7,
#   'InfantryFightingVehicles': 11,
#   'MineresistantAmbushProtected': 2,
#   'InfantryMobilityVehicles': 7,
#   'CommunicationsVehicles': 2,
#   'EngineeringVehicles': 12,
#   'AntitankGuidedMissiles': 3,
#   'Mortars': 1,
#   'Artillery': 4,
#   'MultipleRocketLaunchers': 7,
#   'SurfaceToAirMissileSystems': 3,
#   'Aircraft': 3,
#   'Helicopters': 2,
#   'TrucksVehiclesandJeeps': 37},
#  {'date': '20220619',
#   'Tanks': 767,
#   'ArmouredFightingVehicles': 434,
#   'InfantryFightingVehicles': 865,
#   'ArmouredPersonnelCarriers': 117,
#   'MineResistantAmbushProtected': 27,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 85,
#   'EngineeringVehiclesAndEquipment': 166,
#   'SelfPropelledAntiTankMissileSystems': 21,
#   'HeavyMortars': 14,
#   'TowedArtillery': 65,
#   'SelfPropelledArtillery': 124,
#   'MultipleRocketLaunchers': 79,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 10,
#   'Aircraft': 33,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 87,
#   'NavalShips': 10,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1183},
#  {'date': '20221227',
#   'Tanks': 1584,
#   'ArmouredFightingVehicles': 738,
#   'InfantryFightingVehicles': 1861,
#   'ArmouredPersonnelCarriers': 280,
#   'MineResistantAmbushProtected': 43,
#   'InfantryMobilityVehicles': 175,
#   'CommandPostsAndCommunicationsStations': 212,
#   'EngineeringVehiclesAndEquipment': 259,
#   'SelfPropelledAntiTankMissileSystems': 30,
#   'ArtillerySupportVehiclesAndEquipment': 90,
#   'TowedArtillery': 150,
#   'SelfPropelledArtillery': 299,
#   'MultipleRocketLaunchers': 164,
#   'AntiAircraftGuns': 16,
#   'SelfPropelledAntiAircraftGuns': 23,
#   'SurfaceToAirMissileSystems': 83,
#   'Radars': 20,
#   'JammersAndDeceptionSystems': 22,
#   'Aircraft': 67,
#   'Helicopters': 74,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 150,
#   'NavalShips': 12,
#   'TrucksVehiclesandJeeps': 2146},
#  {'date': '20220622',
#   'Tanks': 770,
#   'ArmouredFightingVehicles': 435,
#   'InfantryFightingVehicles': 873,
#   'ArmouredPersonnelCarriers': 117,
#   'MineResistantAmbushProtected': 27,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 85,
#   'EngineeringVehiclesAndEquipment': 166,
#   'SelfPropelledAntiTankMissileSystems': 21,
#   'HeavyMortars': 14,
#   'TowedArtillery': 65,
#   'SelfPropelledArtillery': 124,
#   'MultipleRocketLaunchers': 79,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 10,
#   'Aircraft': 35,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 88,
#   'NavalShips': 10,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1184},
#  {'date': '20221213',
#   'Tanks': 1570,
#   'ArmouredFightingVehicles': 737,
#   'InfantryFightingVehicles': 1852,
#   'ArmouredPersonnelCarriers': 279,
#   'MineResistantAmbushProtected': 44,
#   'InfantryMobilityVehicles': 175,
#   'CommandPostsAndCommunicationsStations': 207,
#   'EngineeringVehiclesAndEquipment': 252,
#   'SelfPropelledAntiTankMissileSystems': 30,
#   'ArtillerySupportVehiclesAndEquipment': 87,
#   'TowedArtillery': 154,
#   'SelfPropelledArtillery': 299,
#   'MultipleRocketLaunchers': 160,
#   'AntiAircraftGuns': 16,
#   'SelfPropelledAntiAircraftGuns': 22,
#   'SurfaceToAirMissileSystems': 78,
#   'Radars': 21,
#   'JammersAndDeceptionSystems': 22,
#   'Aircraft': 67,
#   'Helicopters': 72,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 149,
#   'NavalShips': 12,
#   'TrucksVehiclesandJeeps': 2114},
#  {'date': '20220515',
#   'Tanks': 669,
#   'ArmouredFightingVehicles': 365,
#   'InfantryFightingVehicles': 721,
#   'ArmouredPersonnelCarriers': 108,
#   'MineResistantAmbushProtected': 26,
#   'InfantryMobilityVehicles': 109,
#   'CommandPostsAndCommunicationsStations': 74,
#   'EngineeringVehiclesAndEquipment': 136,
#   'SelfPropelledAntiTankMissileSystems': 14,
#   'HeavyMortars': 13,
#   'TowedArtillery': 61,
#   'SelfPropelledArtillery': 112,
#   'MultipleRocketLaunchers': 66,
#   'AntiAircraftGuns': 6,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 59,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 8,
#   'Aircraft': 26,
#   'Helicopters': 41,
#   'UnmannedAerialVehicles': 61,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 957},
#  {'date': '20220512',
#   'Tanks': 662,
#   'ArmouredFightingVehicles': 356,
#   'InfantryFightingVehicles': 705,
#   'ArmouredPersonnelCarriers': 108,
#   'MineResistantAmbushProtected': 25,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 73,
#   'EngineeringVehiclesAndEquipment': 133,
#   'SelfPropelledAntiTankMissileSystems': 14,
#   'HeavyMortars': 13,
#   'TowedArtillery': 60,
#   'SelfPropelledArtillery': 110,
#   'MultipleRocketLaunchers': 66,
#   'AntiAircraftGuns': 6,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 59,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 8,
#   'Aircraft': 26,
#   'Helicopters': 41,
#   'UnmannedAerialVehicles': 58,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 948},
#  {'date': '20220923',
#   'Tanks': 1186,
#   'ArmouredFightingVehicles': 610,
#   'InfantryFightingVehicles': 1308,
#   'ArmouredPersonnelCarriers': 165,
#   'MineResistantAmbushProtected': 35,
#   'InfantryMobilityVehicles': 129,
#   'CommandPostsAndCommunicationsStations': 156,
#   'EngineeringVehiclesAndEquipment': 207,
#   'SelfPropelledAntiTankMissileSystems': 25,
#   'HeavyMortars': 21,
#   'ArtillerySupportVehiclesAndEquipment': 61,
#   'TowedArtillery': 94,
#   'SelfPropelledArtillery': 212,
#   'MultipleRocketLaunchers': 109,
#   'AntiAircraftGuns': 10,
#   'SelfPropelledAntiAircraftGuns': 18,
#   'SurfaceToAirMissileSystems': 72,
#   'Radars': 15,
#   'JammersAndDeceptionSystems': 15,
#   'Aircraft': 56,
#   'Helicopters': 50,
#   'UnmannedAerialVehicles': 131,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1670},
#  {'date': '20220327',
#   'Tanks': 310,
#   'ArmouredFightingVehicles': 229,
#   'InfantryFightingVehicles': 303,
#   'ArmouredPersonnelCarriers': 77,
#   'MineResistantAmbushProtected': 12,
#   'InfantryMobilityVehicles': 63,
#   'CommunicationsStations': 12,
#   'EngineeringVehiclesAndEquipment': 60,
#   'AntiTankGuidedMissiles': 63,
#   'ManPortableAirDefenceSystems': 24,
#   'HeavyMortars': 8,
#   'TowedArtillery': 42,
#   'SelfPropelledArtillery': 59,
#   'MultipleRocketLaunchers': 35,
#   'AntiAircraftGuns': 3,
#   'SelfPropelledAntiAircraftGuns': 9,
#   'SurfaceToAirMissileSystems': 40,
#   'Radars': 3,
#   'JammersAndDeceptionSystems': 6,
#   'Aircraft': 16,
#   'Helicopters': 36,
#   'UnmannedAerialVehicles': 16,
#   'NavalShips': 3,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 629},
#  {'date': '20220418',
#   'Tanks': 519,
#   'ArmouredFightingVehicles': 306,
#   'InfantryFightingVehicles': 532,
#   'ArmouredPersonnelCarriers': 101,
#   'MineResistantAmbushProtected': 23,
#   'InfantryMobilityVehicles': 94,
#   'CommandPostsAndCommunicationsStations': 63,
#   'EngineeringVehiclesAndEquipment': 109,
#   'HeavyMortars': 12,
#   'TowedArtillery': 56,
#   'SelfPropelledArtillery': 97,
#   'MultipleRocketLaunchers': 55,
#   'AntiAircraftGuns': 4,
#   'SelfPropelledAntiAircraftGuns': 14,
#   'SurfaceToAirMissileSystems': 52,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 7,
#   'Aircraft': 22,
#   'Helicopters': 35,
#   'UnmannedAerialVehicles': 34,
#   'NavalShips': 4,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 834},
#  {'date': '20221112',
#   'Tanks': 1477,
#   'ArmouredFightingVehicles': 699,
#   'InfantryFightingVehicles': 1712,
#   'ArmouredPersonnelCarriers': 265,
#   'MineResistantAmbushProtected': 43,
#   'InfantryMobilityVehicles': 165,
#   'CommandPostsAndCommunicationsStations': 190,
#   'EngineeringVehiclesAndEquipment': 245,
#   'SelfPropelledAntiTankMissileSystems': 29,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 79,
#   'TowedArtillery': 129,
#   'SelfPropelledArtillery': 270,
#   'MultipleRocketLaunchers': 149,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 22,
#   'SurfaceToAirMissileSystems': 77,
#   'Radars': 19,
#   'JammersAndDeceptionSystems': 19,
#   'Aircraft': 63,
#   'Helicopters': 57,
#   'UnmannedAerialVehicles': 148,
#   'NavalShips': 12,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1950},
#  {'date': '20220618',
#   'Tanks': 762,
#   'ArmouredFightingVehicles': 432,
#   'InfantryFightingVehicles': 854,
#   'ArmouredPersonnelCarriers': 116,
#   'MineResistantAmbushProtected': 27,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 86,
#   'EngineeringVehiclesAndEquipment': 168,
#   'SelfPropelledAntiTankMissileSystems': 21,
#   'HeavyMortars': 13,
#   'TowedArtillery': 64,
#   'SelfPropelledArtillery': 122,
#   'MultipleRocketLaunchers': 82,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 10,
#   'Aircraft': 32,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 86,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1181},
#  {'date': '20220303',
#   'Tanks': 65,
#   'ArmouredFightingVehicles': 55,
#   'InfantryFightingVehicles': 71,
#   'ArmouredPersonnelCarriers': 28,
#   'MineResistantAmbushProtected': 4,
#   'InfantryMobilityVehicles': 24,
#   'CommunicationsStation': 7,
#   'EngineeringVehicles': 24,
#   'AntitankGuidedMissiles': 21,
#   'ManPortableAirDefenceSystems': 1,
#   'HeavyMortars': 2,
#   'TowedArtillery': 8,
#   'SelfPropelledArtillery': 13,
#   'MultipleRocketLaunchers': 13,
#   'SelfpropelledAntiAircraftGuns': 3,
#   'SurfaceToAirMissileSystems': 17,
#   'JammersAndDeceptionSystems': 1,
#   'Aircraft': 4,
#   'UnmannedAerialVehicles': 1,
#   'Helicopters': 7,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 177},
#  {'date': '20220927',
#   'Tanks': 1187,
#   'ArmouredFightingVehicles': 621,
#   'InfantryFightingVehicles': 1324,
#   'ArmouredPersonnelCarriers': 163,
#   'MineResistantAmbushProtected': 35,
#   'InfantryMobilityVehicles': 130,
#   'CommandPostsAndCommunicationsStations': 154,
#   'EngineeringVehiclesAndEquipment': 211,
#   'SelfPropelledAntiTankMissileSystems': 25,
#   'HeavyMortars': 21,
#   'ArtillerySupportVehiclesAndEquipment': 61,
#   'TowedArtillery': 98,
#   'SelfPropelledArtillery': 213,
#   'MultipleRocketLaunchers': 110,
#   'AntiAircraftGuns': 11,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 73,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 16,
#   'Aircraft': 58,
#   'Helicopters': 50,
#   'UnmannedAerialVehicles': 131,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1686},
#  {'date': '20221007',
#   'Tanks': 1298,
#   'ArmouredFightingVehicles': 617,
#   'InfantryFightingVehicles': 1415,
#   'ArmouredPersonnelCarriers': 215,
#   'MineResistantAmbushProtected': 39,
#   'InfantryMobilityVehicles': 143,
#   'CommandPostsAndCommunicationsStations': 164,
#   'EngineeringVehiclesAndEquipment': 222,
#   'SelfPropelledAntiTankMissileSystems': 26,
#   'HeavyMortars': 23,
#   'ArtillerySupportVehiclesAndEquipment': 64,
#   'TowedArtillery': 107,
#   'SelfPropelledArtillery': 220,
#   'MultipleRocketLaunchers': 126,
#   'AntiAircraftGuns': 14,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 73,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 16,
#   'Aircraft': 60,
#   'Helicopters': 52,
#   'UnmannedAerialVehicles': 137,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1768},
#  {'date': '20220802',
#   'Tanks': 923,
#   'ArmouredFightingVehicles': 512,
#   'InfantryFightingVehicles': 993,
#   'ArmouredPersonnelCarriers': 138,
#   'MineResistantAmbushProtected': 32,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 101,
#   'EngineeringVehiclesAndEquipment': 179,
#   'SelfPropelledAntiTankMissileSystems': 22,
#   'HeavyMortars': 14,
#   'TowedArtillery': 74,
#   'SelfPropelledArtillery': 150,
#   'MultipleRocketLaunchers': 94,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 16,
#   'SurfaceToAirMissileSystems': 68,
#   'Radars': 12,
#   'JammersAndDeceptionSystems': 11,
#   'Aircraft': 38,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 102,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1378},
#  {'date': '20220730',
#   'Tanks': 910,
#   'ArmouredFightingVehicles': 506,
#   'InfantryFightingVehicles': 985,
#   'ArmouredPersonnelCarriers': 137,
#   'MineResistantAmbushProtected': 31,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 99,
#   'EngineeringVehiclesAndEquipment': 179,
#   'SelfPropelledAntiTankMissileSystems': 21,
#   'HeavyMortars': 14,
#   'TowedArtillery': 72,
#   'SelfPropelledArtillery': 148,
#   'MultipleRocketLaunchers': 94,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 67,
#   'Radars': 12,
#   'JammersAndDeceptionSystems': 10,
#   'Aircraft': 38,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 101,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1371},
#  {'date': '20221010',
#   'Tanks': 1311,
#   'ArmouredFightingVehicles': 630,
#   'InfantryFightingVehicles': 1442,
#   'ArmouredPersonnelCarriers': 220,
#   'MineResistantAmbushProtected': 40,
#   'InfantryMobilityVehicles': 143,
#   'CommandPostsAndCommunicationsStations': 164,
#   'EngineeringVehiclesAndEquipment': 223,
#   'SelfPropelledAntiTankMissileSystems': 26,
#   'HeavyMortars': 23,
#   'ArtillerySupportVehiclesAndEquipment': 64,
#   'TowedArtillery': 111,
#   'SelfPropelledArtillery': 223,
#   'MultipleRocketLaunchers': 126,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 75,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 16,
#   'Aircraft': 61,
#   'Helicopters': 53,
#   'UnmannedAerialVehicles': 138,
#   'NavalShips': 11,
#   'LogisticsTrains': 4,
#   'TrucksVehiclesandJeeps': 1781},
#  {'date': '20220517',
#   'Tanks': 669,
#   'ArmouredFightingVehicles': 365,
#   'InfantryFightingVehicles': 721,
#   'ArmouredPersonnelCarriers': 108,
#   'MineResistantAmbushProtected': 26,
#   'InfantryMobilityVehicles': 109,
#   'CommandPostsAndCommunicationsStations': 74,
#   'EngineeringVehiclesAndEquipment': 136,
#   'SelfPropelledAntiTankMissileSystems': 14,
#   'HeavyMortars': 13,
#   'TowedArtillery': 61,
#   'SelfPropelledArtillery': 112,
#   'MultipleRocketLaunchers': 66,
#   'AntiAircraftGuns': 6,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 59,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 8,
#   'Aircraft': 26,
#   'Helicopters': 41,
#   'UnmannedAerialVehicles': 61,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 957},
#  {'date': '20221215',
#   'Tanks': 1579,
#   'ArmouredFightingVehicles': 740,
#   'InfantryFightingVehicles': 1861,
#   'ArmouredPersonnelCarriers': 280,
#   'MineResistantAmbushProtected': 44,
#   'InfantryMobilityVehicles': 177,
#   'CommandPostsAndCommunicationsStations': 208,
#   'EngineeringVehiclesAndEquipment': 255,
#   'SelfPropelledAntiTankMissileSystems': 30,
#   'ArtillerySupportVehiclesAndEquipment': 87,
#   'TowedArtillery': 154,
#   'SelfPropelledArtillery': 299,
#   'MultipleRocketLaunchers': 160,
#   'AntiAircraftGuns': 16,
#   'SelfPropelledAntiAircraftGuns': 22,
#   'SurfaceToAirMissileSystems': 79,
#   'Radars': 21,
#   'JammersAndDeceptionSystems': 22,
#   'Aircraft': 67,
#   'Helicopters': 72,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 149,
#   'NavalShips': 12,
#   'TrucksVehiclesandJeeps': 2126},
#  {'date': '20220523',
#   'Tanks': 694,
#   'ArmouredFightingVehicles': 391,
#   'InfantryFightingVehicles': 756,
#   'ArmouredPersonnelCarriers': 110,
#   'MineResistantAmbushProtected': 26,
#   'InfantryMobilityVehicles': 109,
#   'CommandPostsAndCommunicationsStations': 77,
#   'EngineeringVehiclesAndEquipment': 136,
#   'SelfPropelledAntiTankMissileSystems': 15,
#   'HeavyMortars': 13,
#   'TowedArtillery': 61,
#   'SelfPropelledArtillery': 117,
#   'MultipleRocketLaunchers': 69,
#   'AntiAircraftGuns': 6,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 9,
#   'Aircraft': 26,
#   'Helicopters': 42,
#   'UnmannedAerialVehicles': 75,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1075},
#  {'date': '20220307',
#   'Tanks': 136,
#   'ArmouredFightingVehicles': 85,
#   'InfantryFightingVehicles': 126,
#   'ArmouredPersonnelCarriers': 54,
#   'MineResistantAmbushProtected': 4,
#   'InfantryMobilityVehicles': 32,
#   'CommunicationsStations': 8,
#   'EngineeringVehicles': 36,
#   'AntiTankGuidedMissiles': 47,
#   'ManPortableAirDefenceSystems': 16,
#   'HeavyMortars': 3,
#   'TowedArtillery': 24,
#   'SelfPropelledArtillery': 20,
#   'MultipleRocketLaunchers': 19,
#   'SelfpropelledAntiAircraftGuns': 7,
#   'SurfaceToAirMissileSystems': 23,
#   'Radars': 1,
#   'JammersAndDeceptionSystems': 1,
#   'Aircraft': 11,
#   'UnmannedAerialVehicles': 2,
#   'Helicopters': 11,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 261},
#  {'date': '20221116',
#   'Tanks': 1491,
#   'ArmouredFightingVehicles': 705,
#   'InfantryFightingVehicles': 1732,
#   'ArmouredPersonnelCarriers': 266,
#   'MineResistantAmbushProtected': 44,
#   'InfantryMobilityVehicles': 165,
#   'CommandPostsAndCommunicationsStations': 191,
#   'EngineeringVehiclesAndEquipment': 245,
#   'SelfPropelledAntiTankMissileSystems': 29,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 82,
#   'TowedArtillery': 135,
#   'SelfPropelledArtillery': 283,
#   'MultipleRocketLaunchers': 151,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 22,
#   'SurfaceToAirMissileSystems': 77,
#   'Radars': 21,
#   'JammersAndDeceptionSystems': 20,
#   'Aircraft': 63,
#   'Helicopters': 67,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 145,
#   'NavalShips': 12,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1979},
#  {'date': '20221109',
#   'Tanks': 1460,
#   'ArmouredFightingVehicles': 686,
#   'InfantryFightingVehicles': 1669,
#   'ArmouredPersonnelCarriers': 260,
#   'MineResistantAmbushProtected': 42,
#   'InfantryMobilityVehicles': 163,
#   'CommandPostsAndCommunicationsStations': 188,
#   'EngineeringVehiclesAndEquipment': 242,
#   'SelfPropelledAntiTankMissileSystems': 29,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 75,
#   'TowedArtillery': 123,
#   'SelfPropelledArtillery': 261,
#   'MultipleRocketLaunchers': 149,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 21,
#   'SurfaceToAirMissileSystems': 76,
#   'Radars': 18,
#   'JammersAndDeceptionSystems': 18,
#   'Aircraft': 63,
#   'Helicopters': 57,
#   'UnmannedAerialVehicles': 148,
#   'NavalShips': 12,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1920},
#  {'date': '20220723',
#   'Tanks': 882,
#   'ArmouredFightingVehicles': 504,
#   'InfantryFightingVehicles': 958,
#   'ArmouredPersonnelCarriers': 130,
#   'MineResistantAmbushProtected': 30,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 95,
#   'EngineeringVehiclesAndEquipment': 176,
#   'SelfPropelledAntiTankMissileSystems': 21,
#   'HeavyMortars': 14,
#   'TowedArtillery': 72,
#   'SelfPropelledArtillery': 143,
#   'MultipleRocketLaunchers': 93,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 65,
#   'Radars': 12,
#   'JammersAndDeceptionSystems': 10,
#   'Aircraft': 38,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 97,
#   'NavalShips': 10,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1258},
#  {'date': '20221228',
#   'Tanks': 1584,
#   'ArmouredFightingVehicles': 738,
#   'InfantryFightingVehicles': 1861,
#   'ArmouredPersonnelCarriers': 280,
#   'MineResistantAmbushProtected': 43,
#   'InfantryMobilityVehicles': 175,
#   'CommandPostsAndCommunicationsStations': 212,
#   'EngineeringVehiclesAndEquipment': 259,
#   'SelfPropelledAntiTankMissileSystems': 30,
#   'ArtillerySupportVehiclesAndEquipment': 90,
#   'TowedArtillery': 150,
#   'SelfPropelledArtillery': 299,
#   'MultipleRocketLaunchers': 164,
#   'AntiAircraftGuns': 16,
#   'SelfPropelledAntiAircraftGuns': 23,
#   'SurfaceToAirMissileSystems': 83,
#   'Radars': 20,
#   'JammersAndDeceptionSystems': 22,
#   'Aircraft': 67,
#   'Helicopters': 74,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 150,
#   'NavalShips': 12,
#   'TrucksVehiclesandJeeps': 2146},
#  {'date': '20220410',
#   'Tanks': 467,
#   'ArmouredFightingVehicles': 255,
#   'InfantryFightingVehicles': 489,
#   'ArmouredPersonnelCarriers': 96,
#   'MineResistantAmbushProtected': 21,
#   'InfantryMobilityVehicles': 90,
#   'CommandPostsAndCommunicationsStations': 61,
#   'EngineeringVehiclesAndEquipment': 99,
#   'HeavyMortars': 11,
#   'TowedArtillery': 53,
#   'SelfPropelledArtillery': 93,
#   'MultipleRocketLaunchers': 48,
#   'AntiAircraftGuns': 4,
#   'SelfPropelledAntiAircraftGuns': 14,
#   'SurfaceToAirMissileSystems': 51,
#   'Radars': 9,
#   'JammersAndDeceptionSystems': 7,
#   'Aircraft': 20,
#   'Helicopters': 32,
#   'UnmannedAerialVehicles': 27,
#   'NavalShips': 3,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 787},
#  {'date': '20221020',
#   'Tanks': 1398,
#   'ArmouredFightingVehicles': 680,
#   'InfantryFightingVehicles': 1582,
#   'ArmouredPersonnelCarriers': 244,
#   'MineResistantAmbushProtected': 39,
#   'InfantryMobilityVehicles': 160,
#   'CommandPostsAndCommunicationsStations': 178,
#   'EngineeringVehiclesAndEquipment': 234,
#   'SelfPropelledAntiTankMissileSystems': 27,
#   'HeavyMortars': 24,
#   'ArtillerySupportVehiclesAndEquipment': 72,
#   'TowedArtillery': 120,
#   'SelfPropelledArtillery': 248,
#   'MultipleRocketLaunchers': 143,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 78,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 16,
#   'Aircraft': 63,
#   'Helicopters': 54,
#   'UnmannedAerialVehicles': 140,
#   'NavalShips': 11,
#   'LogisticsTrains': 4,
#   'TrucksVehiclesandJeeps': 1891},
#  {'date': '20220602',
#   'Tanks': 749,
#   'ArmouredFightingVehicles': 413,
#   'InfantryFightingVehicles': 825,
#   'ArmouredPersonnelCarriers': 112,
#   'MineResistantAmbushProtected': 26,
#   'InfantryMobilityVehicles': 110,
#   'CommandPostsAndCommunicationsStations': 79,
#   'EngineeringVehiclesAndEquipment': 159,
#   'SelfPropelledAntiTankMissileSystems': 17,
#   'HeavyMortars': 13,
#   'TowedArtillery': 61,
#   'SelfPropelledArtillery': 120,
#   'MultipleRocketLaunchers': 69,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 9,
#   'Aircraft': 30,
#   'Helicopters': 43,
#   'UnmannedAerialVehicles': 80,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1187},
#  {'date': '20220820',
#   'Tanks': 970,
#   'ArmouredFightingVehicles': 514,
#   'InfantryFightingVehicles': 1035,
#   'ArmouredPersonnelCarriers': 142,
#   'MineResistantAmbushProtected': 32,
#   'InfantryMobilityVehicles': 115,
#   'CommandPostsAndCommunicationsStations': 108,
#   'EngineeringVehiclesAndEquipment': 180,
#   'SelfPropelledAntiTankMissileSystems': 22,
#   'HeavyMortars': 15,
#   'ArtillerySupportVehiclesAndEquipment': 53,
#   'TowedArtillery': 75,
#   'SelfPropelledArtillery': 155,
#   'MultipleRocketLaunchers': 94,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 17,
#   'SurfaceToAirMissileSystems': 68,
#   'Radars': 14,
#   'JammersAndDeceptionSystems': 13,
#   'Aircraft': 51,
#   'Helicopters': 51,
#   'UnmannedAerialVehicles': 111,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1389},
#  {'date': '20221029',
#   'Tanks': 1419,
#   'ArmouredFightingVehicles': 683,
#   'InfantryFightingVehicles': 1618,
#   'ArmouredPersonnelCarriers': 250,
#   'MineResistantAmbushProtected': 41,
#   'InfantryMobilityVehicles': 163,
#   'CommandPostsAndCommunicationsStations': 181,
#   'EngineeringVehiclesAndEquipment': 235,
#   'SelfPropelledAntiTankMissileSystems': 28,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 74,
#   'TowedArtillery': 123,
#   'SelfPropelledArtillery': 256,
#   'MultipleRocketLaunchers': 148,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 75,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 17,
#   'Aircraft': 63,
#   'Helicopters': 54,
#   'UnmannedAerialVehicles': 141,
#   'NavalShips': 13,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1894},
#  {'date': '20220302',
#   'Tanks': 55,
#   'ArmouredFightingVehicles': 49,
#   'InfantryFightingVehicles': 62,
#   'ArmouredPersonnelCarriers': 24,
#   'MineResistantAmbushProtected': 3,
#   'InfantryMobilityVehicles': 24,
#   'CommunicationsStation': 5,
#   'EngineeringVehicles': 23,
#   'AntitankGuidedMissiles': 18,
#   'ManPortableAirDefenceSystems': 1,
#   'HeavyMortars': 2,
#   'TowedArtillery': 6,
#   'SelfPropelledArtillery': 10,
#   'MultipleRocketLaunchers': 11,
#   'SelfpropelledAntiAircraftGuns': 3,
#   'SurfaceToAirMissileSystems': 17,
#   'JammersAndDeceptionSystems': 1,
#   'Aircraft': 4,
#   'UnmannedAerialVehicles': 1,
#   'Helicopters': 7,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 162},
#  {'date': '20220614',
#   'Tanks': 774,
#   'ArmouredFightingVehicles': 432,
#   'InfantryFightingVehicles': 853,
#   'ArmouredPersonnelCarriers': 116,
#   'MineResistantAmbushProtected': 27,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 80,
#   'EngineeringVehiclesAndEquipment': 157,
#   'SelfPropelledAntiTankMissileSystems': 20,
#   'HeavyMortars': 13,
#   'TowedArtillery': 64,
#   'SelfPropelledArtillery': 121,
#   'MultipleRocketLaunchers': 82,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 9,
#   'Aircraft': 31,
#   'Helicopters': 47,
#   'UnmannedAerialVehicles': 83,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1226},
#  {'date': '20220725',
#   'Tanks': 887,
#   'ArmouredFightingVehicles': 507,
#   'InfantryFightingVehicles': 963,
#   'ArmouredPersonnelCarriers': 130,
#   'MineResistantAmbushProtected': 30,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 96,
#   'EngineeringVehiclesAndEquipment': 175,
#   'SelfPropelledAntiTankMissileSystems': 21,
#   'HeavyMortars': 14,
#   'TowedArtillery': 72,
#   'SelfPropelledArtillery': 146,
#   'MultipleRocketLaunchers': 94,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 67,
#   'Radars': 12,
#   'JammersAndDeceptionSystems': 10,
#   'Aircraft': 38,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 99,
#   'NavalShips': 11,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1265},
#  {'date': '20220930',
#   'Tanks': 1224,
#   'ArmouredFightingVehicles': 589,
#   'InfantryFightingVehicles': 1355,
#   'ArmouredPersonnelCarriers': 204,
#   'MineResistantAmbushProtected': 36,
#   'InfantryMobilityVehicles': 137,
#   'CommandPostsAndCommunicationsStations': 161,
#   'EngineeringVehiclesAndEquipment': 216,
#   'SelfPropelledAntiTankMissileSystems': 25,
#   'HeavyMortars': 21,
#   'ArtillerySupportVehiclesAndEquipment': 63,
#   'TowedArtillery': 99,
#   'SelfPropelledArtillery': 218,
#   'MultipleRocketLaunchers': 115,
#   'AntiAircraftGuns': 11,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 73,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 16,
#   'Aircraft': 58,
#   'Helicopters': 50,
#   'UnmannedAerialVehicles': 133,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1715},
#  {'date': '20221202',
#   'Tanks': 1530,
#   'ArmouredFightingVehicles': 729,
#   'InfantryFightingVehicles': 1793,
#   'ArmouredPersonnelCarriers': 274,
#   'MineResistantAmbushProtected': 44,
#   'InfantryMobilityVehicles': 170,
#   'CommandPostsAndCommunicationsStations': 199,
#   'EngineeringVehiclesAndEquipment': 247,
#   'SelfPropelledAntiTankMissileSystems': 29,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 86,
#   'TowedArtillery': 143,
#   'SelfPropelledArtillery': 293,
#   'MultipleRocketLaunchers': 159,
#   'AntiAircraftGuns': 16,
#   'SelfPropelledAntiAircraftGuns': 22,
#   'SurfaceToAirMissileSystems': 77,
#   'Radars': 21,
#   'JammersAndDeceptionSystems': 22,
#   'Aircraft': 63,
#   'Helicopters': 71,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 148,
#   'NavalShips': 12,
#   'TrucksVehiclesandJeeps': 2029},
#  {'date': '20220612',
#   'Tanks': 774,
#   'ArmouredFightingVehicles': 426,
#   'InfantryFightingVehicles': 848,
#   'ArmouredPersonnelCarriers': 116,
#   'MineResistantAmbushProtected': 27,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 80,
#   'EngineeringVehiclesAndEquipment': 157,
#   'SelfPropelledAntiTankMissileSystems': 20,
#   'HeavyMortars': 13,
#   'TowedArtillery': 64,
#   'SelfPropelledArtillery': 121,
#   'MultipleRocketLaunchers': 79,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 9,
#   'Aircraft': 31,
#   'Helicopters': 47,
#   'UnmannedAerialVehicles': 82,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1226},
#  {'date': '20220331',
#   'Tanks': 352,
#   'ArmouredFightingVehicles': 244,
#   'InfantryFightingVehicles': 346,
#   'ArmouredPersonnelCarriers': 81,
#   'MineResistantAmbushProtected': 14,
#   'InfantryMobilityVehicles': 70,
#   'CommunicationsStations': 13,
#   'EngineeringVehiclesAndEquipment': 67,
#   'AntiTankGuidedMissiles': 76,
#   'ManPortableAirDefenceSystems': 24,
#   'HeavyMortars': 9,
#   'TowedArtillery': 46,
#   'SelfPropelledArtillery': 63,
#   'MultipleRocketLaunchers': 39,
#   'AntiAircraftGuns': 3,
#   'SelfPropelledAntiAircraftGuns': 10,
#   'SurfaceToAirMissileSystems': 41,
#   'Radars': 3,
#   'JammersAndDeceptionSystems': 6,
#   'Aircraft': 17,
#   'Helicopters': 35,
#   'UnmannedAerialVehicles': 18,
#   'NavalShips': 3,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 652},
#  {'date': '20221208',
#   'Tanks': 1551,
#   'ArmouredFightingVehicles': 739,
#   'InfantryFightingVehicles': 1832,
#   'ArmouredPersonnelCarriers': 275,
#   'MineResistantAmbushProtected': 44,
#   'InfantryMobilityVehicles': 175,
#   'CommandPostsAndCommunicationsStations': 205,
#   'EngineeringVehiclesAndEquipment': 252,
#   'SelfPropelledAntiTankMissileSystems': 30,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 86,
#   'TowedArtillery': 145,
#   'SelfPropelledArtillery': 298,
#   'MultipleRocketLaunchers': 159,
#   'AntiAircraftGuns': 16,
#   'SelfPropelledAntiAircraftGuns': 22,
#   'SurfaceToAirMissileSystems': 78,
#   'Radars': 21,
#   'JammersAndDeceptionSystems': 22,
#   'Aircraft': 66,
#   'Helicopters': 72,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 149,
#   'NavalShips': 12,
#   'TrucksVehiclesandJeeps': 2102},
#  {'date': '20220304',
#   'Tanks': 91,
#   'ArmouredFightingVehicles': 65,
#   'InfantryFightingVehicles': 80,
#   'ArmouredPersonnelCarriers': 33,
#   'MineResistantAmbushProtected': 4,
#   'InfantryMobilityVehicles': 25,
#   'CommunicationsStation': 8,
#   'EngineeringVehicles': 26,
#   'AntitankGuidedMissiles': 26,
#   'ManPortableAirDefenceSystems': 3,
#   'HeavyMortars': 3,
#   'TowedArtillery': 9,
#   'SelfPropelledArtillery': 15,
#   'MultipleRocketLaunchers': 15,
#   'SelfpropelledAntiAircraftGuns': 7,
#   'SurfaceToAirMissileSystems': 18,
#   'JammersAndDeceptionSystems': 1,
#   'Aircraft': 6,
#   'UnmannedAerialVehicles': 1,
#   'Helicopters': 8,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 204},
#  {'date': '20221110',
#   'Tanks': 1465,
#   'ArmouredFightingVehicles': 691,
#   'InfantryFightingVehicles': 1682,
#   'ArmouredPersonnelCarriers': 259,
#   'MineResistantAmbushProtected': 42,
#   'InfantryMobilityVehicles': 163,
#   'CommandPostsAndCommunicationsStations': 190,
#   'EngineeringVehiclesAndEquipment': 242,
#   'SelfPropelledAntiTankMissileSystems': 29,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 78,
#   'TowedArtillery': 128,
#   'SelfPropelledArtillery': 264,
#   'MultipleRocketLaunchers': 149,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 21,
#   'SurfaceToAirMissileSystems': 76,
#   'Radars': 18,
#   'JammersAndDeceptionSystems': 18,
#   'Aircraft': 63,
#   'Helicopters': 57,
#   'UnmannedAerialVehicles': 148,
#   'NavalShips': 12,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1927},
#  {'date': '20220611',
#   'Tanks': 767,
#   'ArmouredFightingVehicles': 422,
#   'InfantryFightingVehicles': 846,
#   'ArmouredPersonnelCarriers': 116,
#   'MineResistantAmbushProtected': 27,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 80,
#   'EngineeringVehiclesAndEquipment': 157,
#   'SelfPropelledAntiTankMissileSystems': 20,
#   'HeavyMortars': 13,
#   'TowedArtillery': 64,
#   'SelfPropelledArtillery': 120,
#   'MultipleRocketLaunchers': 79,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 9,
#   'Aircraft': 31,
#   'Helicopters': 46,
#   'UnmannedAerialVehicles': 82,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1215},
#  {'date': '20221106',
#   'Tanks': 1420,
#   'ArmouredFightingVehicles': 683,
#   'InfantryFightingVehicles': 1626,
#   'ArmouredPersonnelCarriers': 252,
#   'MineResistantAmbushProtected': 41,
#   'InfantryMobilityVehicles': 161,
#   'CommandPostsAndCommunicationsStations': 184,
#   'EngineeringVehiclesAndEquipment': 237,
#   'SelfPropelledAntiTankMissileSystems': 28,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 74,
#   'TowedArtillery': 123,
#   'SelfPropelledArtillery': 257,
#   'MultipleRocketLaunchers': 146,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 75,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 18,
#   'Aircraft': 63,
#   'Helicopters': 57,
#   'UnmannedAerialVehicles': 141,
#   'NavalShips': 12,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1903},
#  {'date': '20220830',
#   'Tanks': 990,
#   'ArmouredFightingVehicles': 511,
#   'InfantryFightingVehicles': 1065,
#   'ArmouredPersonnelCarriers': 143,
#   'MineResistantAmbushProtected': 30,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 113,
#   'EngineeringVehiclesAndEquipment': 184,
#   'SelfPropelledAntiTankMissileSystems': 22,
#   'HeavyMortars': 15,
#   'ArtillerySupportVehiclesAndEquipment': 53,
#   'TowedArtillery': 79,
#   'SelfPropelledArtillery': 163,
#   'MultipleRocketLaunchers': 90,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 17,
#   'SurfaceToAirMissileSystems': 67,
#   'Radars': 14,
#   'JammersAndDeceptionSystems': 13,
#   'Aircraft': 52,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 120,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1452},
#  {'date': '20221207',
#   'Tanks': 1545,
#   'ArmouredFightingVehicles': 735,
#   'InfantryFightingVehicles': 1821,
#   'ArmouredPersonnelCarriers': 275,
#   'MineResistantAmbushProtected': 44,
#   'InfantryMobilityVehicles': 172,
#   'CommandPostsAndCommunicationsStations': 204,
#   'EngineeringVehiclesAndEquipment': 249,
#   'SelfPropelledAntiTankMissileSystems': 30,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 86,
#   'TowedArtillery': 144,
#   'SelfPropelledArtillery': 297,
#   'MultipleRocketLaunchers': 159,
#   'AntiAircraftGuns': 16,
#   'SelfPropelledAntiAircraftGuns': 22,
#   'SurfaceToAirMissileSystems': 78,
#   'Radars': 21,
#   'JammersAndDeceptionSystems': 22,
#   'Aircraft': 66,
#   'Helicopters': 72,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 149,
#   'NavalShips': 12,
#   'TrucksVehiclesandJeeps': 2051},
#  {'date': '20220801',
#   'Tanks': 920,
#   'ArmouredFightingVehicles': 509,
#   'InfantryFightingVehicles': 990,
#   'ArmouredPersonnelCarriers': 137,
#   'MineResistantAmbushProtected': 32,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 101,
#   'EngineeringVehiclesAndEquipment': 179,
#   'SelfPropelledAntiTankMissileSystems': 22,
#   'HeavyMortars': 14,
#   'TowedArtillery': 74,
#   'SelfPropelledArtillery': 150,
#   'MultipleRocketLaunchers': 94,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 16,
#   'SurfaceToAirMissileSystems': 67,
#   'Radars': 12,
#   'JammersAndDeceptionSystems': 11,
#   'Aircraft': 38,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 102,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1377},
#  {'date': '20221102',
#   'Tanks': 1420,
#   'ArmouredFightingVehicles': 683,
#   'InfantryFightingVehicles': 1626,
#   'ArmouredPersonnelCarriers': 252,
#   'MineResistantAmbushProtected': 41,
#   'InfantryMobilityVehicles': 161,
#   'CommandPostsAndCommunicationsStations': 184,
#   'EngineeringVehiclesAndEquipment': 237,
#   'SelfPropelledAntiTankMissileSystems': 28,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 74,
#   'TowedArtillery': 123,
#   'SelfPropelledArtillery': 257,
#   'MultipleRocketLaunchers': 146,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 75,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 18,
#   'Aircraft': 63,
#   'Helicopters': 57,
#   'UnmannedAerialVehicles': 143,
#   'NavalShips': 12,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1903},
#  {'date': '20220606',
#   'Tanks': 761,
#   'ArmouredFightingVehicles': 417,
#   'InfantryFightingVehicles': 832,
#   'ArmouredPersonnelCarriers': 115,
#   'MineResistantAmbushProtected': 26,
#   'InfantryMobilityVehicles': 110,
#   'CommandPostsAndCommunicationsStations': 80,
#   'EngineeringVehiclesAndEquipment': 159,
#   'SelfPropelledAntiTankMissileSystems': 19,
#   'HeavyMortars': 13,
#   'TowedArtillery': 62,
#   'SelfPropelledArtillery': 119,
#   'MultipleRocketLaunchers': 69,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 9,
#   'Aircraft': 30,
#   'Helicopters': 45,
#   'UnmannedAerialVehicles': 80,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1191},
#  {'date': '20221128',
#   'Tanks': 1520,
# ...
#   'TowedArtillery': 123,
#   'SelfPropelledArtillery': 253,
#   'MultipleRocketLaunchers': 148,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 75,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 16,
#   'Aircraft': 63,
#   'Helicopters': 54,
#   'UnmannedAerialVehicles': 141,
#   'NavalShips': 11,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1933},
#  {'date': '20220311',
#   'Tanks': 190,
#   'ArmouredFightingVehicles': 111,
#   'InfantryFightingVehicles': 165,
#   'ArmouredPersonnelCarriers': 63,
#   'MineResistantAmbushProtected': 7,
#   'InfantryMobilityVehicles': 35,
#   'CommunicationsStations': 8,
#   'EngineeringVehicles': 36,
#   'AntiTankGuidedMissiles': 48,
#   'ManPortableAirDefenceSystems': 16,
#   'HeavyMortars': 5,
#   'TowedArtillery': 26,
#   'SelfPropelledArtillery': 27,
#   'MultipleRocketLaunchers': 19,
#   'AntiAircraftGuns': 1,
#   'SelfPropelledAntiAircraftGuns': 8,
#   'SurfaceToAirMissileSystems': 29,
#   'Radars': 1,
#   'JammersAndDeceptionSystems': 1,
#   'Aircraft': 12,
#   'UnmannedAerialVehicles': 4,
#   'Helicopters': 13,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 334},
#  {'date': '20220921',
#   'Tanks': 1176,
#   'ArmouredFightingVehicles': 603,
#   'InfantryFightingVehicles': 1291,
#   'ArmouredPersonnelCarriers': 164,
#   'MineResistantAmbushProtected': 35,
#   'InfantryMobilityVehicles': 129,
#   'CommandPostsAndCommunicationsStations': 154,
#   'EngineeringVehiclesAndEquipment': 205,
#   'SelfPropelledAntiTankMissileSystems': 25,
#   'HeavyMortars': 21,
#   'ArtillerySupportVehiclesAndEquipment': 61,
#   'TowedArtillery': 92,
#   'SelfPropelledArtillery': 210,
#   'MultipleRocketLaunchers': 109,
#   'AntiAircraftGuns': 10,
#   'SelfPropelledAntiAircraftGuns': 18,
#   'SurfaceToAirMissileSystems': 72,
#   'Radars': 15,
#   'JammersAndDeceptionSystems': 15,
#   'Aircraft': 56,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 128,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1654},
#  {'date': '20220609',
#   'Tanks': 762,
#   'ArmouredFightingVehicles': 420,
#   'InfantryFightingVehicles': 840,
#   'ArmouredPersonnelCarriers': 115,
#   'MineResistantAmbushProtected': 27,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 80,
#   'EngineeringVehiclesAndEquipment': 158,
#   'SelfPropelledAntiTankMissileSystems': 20,
#   'HeavyMortars': 13,
#   'TowedArtillery': 63,
#   'SelfPropelledArtillery': 119,
#   'MultipleRocketLaunchers': 71,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 9,
#   'Aircraft': 30,
#   'Helicopters': 46,
#   'UnmannedAerialVehicles': 81,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1202},
#  {'date': '20220407',
#   'Tanks': 448,
#   'ArmouredFightingVehicles': 284,
#   'InfantryFightingVehicles': 465,
#   'ArmouredPersonnelCarriers': 90,
#   'MineResistantAmbushProtected': 21,
#   'InfantryMobilityVehicles': 81,
#   'CommunicationsStations': 19,
#   'EngineeringVehiclesAndEquipment': 86,
#   'HeavyMortars': 11,
#   'TowedArtillery': 52,
#   'SelfPropelledArtillery': 83,
#   'MultipleRocketLaunchers': 49,
#   'AntiAircraftGuns': 4,
#   'SelfPropelledAntiAircraftGuns': 13,
#   'SurfaceToAirMissileSystems': 51,
#   'Radars': 9,
#   'JammersAndDeceptionSystems': 7,
#   'Aircraft': 20,
#   'Helicopters': 32,
#   'UnmannedAerialVehicles': 22,
#   'NavalShips': 3,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 750},
#  {'date': '20220821',
#   'Tanks': 968,
#   'ArmouredFightingVehicles': 502,
#   'InfantryFightingVehicles': 1047,
#   'ArmouredPersonnelCarriers': 142,
#   'MineResistantAmbushProtected': 31,
#   'InfantryMobilityVehicles': 115,
#   'CommandPostsAndCommunicationsStations': 108,
#   'EngineeringVehiclesAndEquipment': 180,
#   'SelfPropelledAntiTankMissileSystems': 22,
#   'HeavyMortars': 15,
#   'ArtillerySupportVehiclesAndEquipment': 53,
#   'TowedArtillery': 75,
#   'SelfPropelledArtillery': 155,
#   'MultipleRocketLaunchers': 94,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 17,
#   'SurfaceToAirMissileSystems': 68,
#   'Radars': 14,
#   'JammersAndDeceptionSystems': 13,
#   'Aircraft': 51,
#   'Helicopters': 51,
#   'UnmannedAerialVehicles': 111,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1389},
#  {'date': '20221229',
#   'Tanks': 1593,
#   'ArmouredFightingVehicles': 742,
#   'InfantryFightingVehicles': 1869,
#   'ArmouredPersonnelCarriers': 280,
#   'MineResistantAmbushProtected': 43,
#   'InfantryMobilityVehicles': 176,
#   'CommandPostsAndCommunicationsStations': 214,
#   'EngineeringVehiclesAndEquipment': 260,
#   'SelfPropelledAntiTankMissileSystems': 30,
#   'ArtillerySupportVehiclesAndEquipment': 90,
#   'TowedArtillery': 151,
#   'SelfPropelledArtillery': 300,
#   'MultipleRocketLaunchers': 166,
#   'AntiAircraftGuns': 16,
#   'SelfPropelledAntiAircraftGuns': 23,
#   'SurfaceToAirMissileSystems': 83,
#   'Radars': 20,
#   'JammersAndDeceptionSystems': 22,
#   'Aircraft': 67,
#   'Helicopters': 74,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 150,
#   'NavalShips': 12,
#   'TrucksVehiclesandJeeps': 2149},
#  {'date': '20220531',
#   'Tanks': 742,
#   'ArmouredFightingVehicles': 412,
#   'InfantryFightingVehicles': 819,
#   'ArmouredPersonnelCarriers': 112,
#   'MineResistantAmbushProtected': 26,
#   'InfantryMobilityVehicles': 110,
#   'CommandPostsAndCommunicationsStations': 79,
#   'EngineeringVehiclesAndEquipment': 159,
#   'SelfPropelledAntiTankMissileSystems': 17,
#   'HeavyMortars': 13,
#   'TowedArtillery': 61,
#   'SelfPropelledArtillery': 120,
#   'MultipleRocketLaunchers': 69,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 9,
#   'Aircraft': 29,
#   'Helicopters': 43,
#   'UnmannedAerialVehicles': 76,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1186},
#  {'date': '20221214',
#   'Tanks': 1579,
#   'ArmouredFightingVehicles': 740,
#   'InfantryFightingVehicles': 1861,
#   'ArmouredPersonnelCarriers': 280,
#   'MineResistantAmbushProtected': 44,
#   'InfantryMobilityVehicles': 177,
#   'CommandPostsAndCommunicationsStations': 208,
#   'EngineeringVehiclesAndEquipment': 255,
#   'SelfPropelledAntiTankMissileSystems': 30,
#   'ArtillerySupportVehiclesAndEquipment': 87,
#   'TowedArtillery': 154,
#   'SelfPropelledArtillery': 299,
#   'MultipleRocketLaunchers': 160,
#   'AntiAircraftGuns': 16,
#   'SelfPropelledAntiAircraftGuns': 22,
#   'SurfaceToAirMissileSystems': 79,
#   'Radars': 21,
#   'JammersAndDeceptionSystems': 22,
#   'Aircraft': 67,
#   'Helicopters': 72,
#   'UnmannedCombatAerialVehicles': 4,
#   'ReconnaissanceUnmannedAerialVehicles': 149,
#   'NavalShips': 12,
#   'TrucksVehiclesandJeeps': 2126},
#  {'date': '20220615',
#   'Tanks': 774,
#   'ArmouredFightingVehicles': 432,
#   'InfantryFightingVehicles': 853,
#   'ArmouredPersonnelCarriers': 116,
#   'MineResistantAmbushProtected': 27,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 80,
#   'EngineeringVehiclesAndEquipment': 157,
#   'SelfPropelledAntiTankMissileSystems': 20,
#   'HeavyMortars': 13,
#   'TowedArtillery': 64,
#   'SelfPropelledArtillery': 121,
#   'MultipleRocketLaunchers': 82,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 9,
#   'Aircraft': 31,
#   'Helicopters': 47,
#   'UnmannedAerialVehicles': 83,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1226},
#  {'date': '20220905',
#   'Tanks': 1012,
#   'ArmouredFightingVehicles': 523,
#   'InfantryFightingVehicles': 1098,
#   'ArmouredPersonnelCarriers': 146,
#   'MineResistantAmbushProtected': 30,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 114,
#   'EngineeringVehiclesAndEquipment': 185,
#   'SelfPropelledAntiTankMissileSystems': 23,
#   'HeavyMortars': 16,
#   'ArtillerySupportVehiclesAndEquipment': 53,
#   'TowedArtillery': 79,
#   'SelfPropelledArtillery': 166,
#   'MultipleRocketLaunchers': 90,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 17,
#   'SurfaceToAirMissileSystems': 71,
#   'Radars': 14,
#   'JammersAndDeceptionSystems': 14,
#   'Aircraft': 52,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 124,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1461},
#  {'date': '20221101',
#   'Tanks': 1417,
#   'ArmouredFightingVehicles': 682,
#   'InfantryFightingVehicles': 1618,
#   'ArmouredPersonnelCarriers': 251,
#   'MineResistantAmbushProtected': 41,
#   'InfantryMobilityVehicles': 161,
#   'CommandPostsAndCommunicationsStations': 184,
#   'EngineeringVehiclesAndEquipment': 237,
#   'SelfPropelledAntiTankMissileSystems': 28,
#   'HeavyMortars': 25,
#   'ArtillerySupportVehiclesAndEquipment': 74,
#   'TowedArtillery': 123,
#   'SelfPropelledArtillery': 257,
#   'MultipleRocketLaunchers': 146,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 73,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 17,
#   'Aircraft': 63,
#   'Helicopters': 57,
#   'UnmannedAerialVehicles': 141,
#   'NavalShips': 13,
#   'LogisticsTrains': 6,
#   'TrucksVehiclesandJeeps': 1893},
#  {'date': '20220809',
#   'Tanks': 933,
#   'ArmouredFightingVehicles': 528,
#   'InfantryFightingVehicles': 1016,
#   'ArmouredPersonnelCarriers': 142,
#   'MineResistantAmbushProtected': 32,
#   'InfantryMobilityVehicles': 114,
#   'CommandPostsAndCommunicationsStations': 105,
#   'EngineeringVehiclesAndEquipment': 178,
#   'SelfPropelledAntiTankMissileSystems': 22,
#   'HeavyMortars': 14,
#   'TowedArtillery': 75,
#   'SelfPropelledArtillery': 151,
#   'MultipleRocketLaunchers': 92,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 17,
#   'SurfaceToAirMissileSystems': 68,
#   'Radars': 13,
#   'JammersAndDeceptionSystems': 11,
#   'Aircraft': 39,
#   'Helicopters': 49,
#   'UnmannedAerialVehicles': 104,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1390},
#  {'date': '20220601',
#   'Tanks': 747,
#   'ArmouredFightingVehicles': 413,
#   'InfantryFightingVehicles': 825,
#   'ArmouredPersonnelCarriers': 112,
#   'MineResistantAmbushProtected': 26,
#   'InfantryMobilityVehicles': 110,
#   'CommandPostsAndCommunicationsStations': 79,
#   'EngineeringVehiclesAndEquipment': 159,
#   'SelfPropelledAntiTankMissileSystems': 17,
#   'HeavyMortars': 13,
#   'TowedArtillery': 61,
#   'SelfPropelledArtillery': 120,
#   'MultipleRocketLaunchers': 69,
#   'AntiAircraftGuns': 7,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 63,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 9,
#   'Aircraft': 29,
#   'Helicopters': 43,
#   'UnmannedAerialVehicles': 77,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 1187},
#  {'date': '20220421',
#   'Tanks': 531,
#   'ArmouredFightingVehicles': 314,
#   'InfantryFightingVehicles': 561,
#   'ArmouredPersonnelCarriers': 101,
#   'MineResistantAmbushProtected': 24,
#   'InfantryMobilityVehicles': 95,
#   'CommandPostsAndCommunicationsStations': 63,
#   'EngineeringVehiclesAndEquipment': 111,
#   'HeavyMortars': 12,
#   'TowedArtillery': 56,
#   'SelfPropelledArtillery': 97,
#   'MultipleRocketLaunchers': 58,
#   'AntiAircraftGuns': 4,
#   'SelfPropelledAntiAircraftGuns': 14,
#   'SurfaceToAirMissileSystems': 53,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 7,
#   'Aircraft': 24,
#   'Helicopters': 37,
#   'UnmannedAerialVehicles': 41,
#   'NavalShips': 4,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 856},
#  {'date': '20220914',
#   'Tanks': 1122,
#   'ArmouredFightingVehicles': 572,
#   'InfantryFightingVehicles': 1253,
#   'ArmouredPersonnelCarriers': 163,
#   'MineResistantAmbushProtected': 33,
#   'InfantryMobilityVehicles': 126,
#   'CommandPostsAndCommunicationsStations': 140,
#   'EngineeringVehiclesAndEquipment': 201,
#   'SelfPropelledAntiTankMissileSystems': 25,
#   'HeavyMortars': 17,
#   'ArtillerySupportVehiclesAndEquipment': 59,
#   'TowedArtillery': 89,
#   'SelfPropelledArtillery': 200,
#   'MultipleRocketLaunchers': 109,
#   'AntiAircraftGuns': 9,
#   'SelfPropelledAntiAircraftGuns': 18,
#   'SurfaceToAirMissileSystems': 72,
#   'Radars': 15,
#   'JammersAndDeceptionSystems': 15,
#   'Aircraft': 56,
#   'Helicopters': 48,
#   'UnmannedAerialVehicles': 127,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1566},
#  {'date': '20220520',
#   'Tanks': 682,
#   'ArmouredFightingVehicles': 368,
#   'InfantryFightingVehicles': 730,
#   'ArmouredPersonnelCarriers': 108,
#   'MineResistantAmbushProtected': 26,
#   'InfantryMobilityVehicles': 109,
#   'CommandPostsAndCommunicationsStations': 75,
#   'EngineeringVehiclesAndEquipment': 136,
#   'SelfPropelledAntiTankMissileSystems': 14,
#   'HeavyMortars': 13,
#   'TowedArtillery': 61,
#   'SelfPropelledArtillery': 112,
#   'MultipleRocketLaunchers': 66,
#   'AntiAircraftGuns': 6,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 62,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 8,
#   'Aircraft': 26,
#   'Helicopters': 42,
#   'UnmannedAerialVehicles': 63,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 958},
#  {'date': '20220510',
#   'Tanks': 645,
#   'ArmouredFightingVehicles': 345,
#   'InfantryFightingVehicles': 704,
#   'ArmouredPersonnelCarriers': 108,
#   'MineResistantAmbushProtected': 25,
#   'InfantryMobilityVehicles': 108,
#   'CommandPostsAndCommunicationsStations': 73,
#   'EngineeringVehiclesAndEquipment': 133,
#   'SelfPropelledAntiTankMissileSystems': 14,
#   'HeavyMortars': 13,
#   'TowedArtillery': 59,
#   'SelfPropelledArtillery': 107,
#   'MultipleRocketLaunchers': 63,
#   'AntiAircraftGuns': 6,
#   'SelfPropelledAntiAircraftGuns': 15,
#   'SurfaceToAirMissileSystems': 59,
#   'Radars': 10,
#   'JammersAndDeceptionSystems': 8,
#   'Aircraft': 26,
#   'Helicopters': 41,
#   'UnmannedAerialVehicles': 56,
#   'NavalShips': 9,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 942},
#  {'date': '20221002',
#   'Tanks': 1241,
#   'ArmouredFightingVehicles': 594,
#   'InfantryFightingVehicles': 1377,
#   'ArmouredPersonnelCarriers': 205,
#   'MineResistantAmbushProtected': 36,
#   'InfantryMobilityVehicles': 141,
#   'CommandPostsAndCommunicationsStations': 163,
#   'EngineeringVehiclesAndEquipment': 219,
#   'SelfPropelledAntiTankMissileSystems': 26,
#   'HeavyMortars': 21,
#   'ArtillerySupportVehiclesAndEquipment': 63,
#   'TowedArtillery': 100,
#   'SelfPropelledArtillery': 218,
#   'MultipleRocketLaunchers': 117,
#   'AntiAircraftGuns': 11,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 73,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 16,
#   'Aircraft': 59,
#   'Helicopters': 52,
#   'UnmannedAerialVehicles': 134,
#   'NavalShips': 11,
#   'LogisticsTrains': 3,
#   'TrucksVehiclesandJeeps': 1731},
#  {'date': '20220318',
#   'Tanks': 244,
#   'ArmouredFightingVehicles': 163,
#   'InfantryFightingVehicles': 225,
#   'ArmouredPersonnelCarriers': 70,
#   'MineResistantAmbushProtected': 11,
#   'InfantryMobilityVehicles': 52,
#   'CommunicationsStations': 9,
#   'EngineeringVehicles': 43,
#   'AntiTankGuidedMissiles': 61,
#   'ManPortableAirDefenceSystems': 24,
#   'HeavyMortars': 5,
#   'TowedArtillery': 33,
#   'SelfPropelledArtillery': 37,
#   'MultipleRocketLaunchers': 27,
#   'AntiAircraftGuns': 2,
#   'SelfPropelledAntiAircraftGuns': 9,
#   'SurfaceToAirMissileSystems': 35,
#   'Radars': 2,
#   'JammersAndDeceptionSystems': 4,
#   'Aircraft': 13,
#   'UnmannedAerialVehicles': 9,
#   'Helicopters': 34,
#   'LogisticsTrains': 2,
#   'TrucksVehiclesandJeeps': 499},
#  {'date': '20221024',
#   'Tanks': 1415,
#   'ArmouredFightingVehicles': 682,
#   'InfantryFightingVehicles': 1610,
#   'ArmouredPersonnelCarriers': 246,
#   'MineResistantAmbushProtected': 41,
#   'InfantryMobilityVehicles': 161,
#   'CommandPostsAndCommunicationsStations': 183,
#   'EngineeringVehiclesAndEquipment': 235,
#   'SelfPropelledAntiTankMissileSystems': 28,
#   'HeavyMortars': 24,
#   'ArtillerySupportVehiclesAndEquipment': 74,
#   'TowedArtillery': 120,
#   'SelfPropelledArtillery': 251,
#   'MultipleRocketLaunchers': 145,
#   'AntiAircraftGuns': 15,
#   'SelfPropelledAntiAircraftGuns': 20,
#   'SurfaceToAirMissileSystems': 78,
#   'Radars': 16,
#   'JammersAndDeceptionSystems': 16,
#   'Aircraft': 63,
#   'Helicopters': 54,
#   'UnmannedAerialVehicles': 141,
#   'NavalShips': 11,
#   'LogisticsTrains': 4,
#   'TrucksVehiclesandJeeps': 1902}]

# %%
russia_df = pl.DataFrame(russia).sort(by="date")
russia_df
# Out:
# shape: (311, 39)
# ┌──────────┬───────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ date     ┆ Tanks ┆ ArmouredFi ┆ InfantryFi ┆ ... ┆ AntiTankGu ┆ ManPortabl ┆ Communicat ┆ Selfpropel │
# │ ---      ┆ ---   ┆ ghtingVehi ┆ ghtingVehi ┆     ┆ idedMissil ┆ eAirDefenc ┆ ionsStatio ┆ ledAntiAir │
# │ str      ┆ i64   ┆ cles       ┆ cles       ┆     ┆ es         ┆ eSystems   ┆ n          ┆ craftGuns  │
# │          ┆       ┆ ---        ┆ ---        ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │          ┆       ┆ i64        ┆ i64        ┆     ┆ i64        ┆ i64        ┆ i64        ┆ i64        │
# ╞══════════╪═══════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 20220224 ┆ 1     ┆ 5          ┆ 1          ┆ ... ┆ null       ┆ null       ┆ null       ┆ null       │
# │ 20220225 ┆ 2     ┆ 7          ┆ 4          ┆ ... ┆ null       ┆ null       ┆ null       ┆ null       │
# │ 20220226 ┆ 7     ┆ 7          ┆ 11         ┆ ... ┆ null       ┆ null       ┆ null       ┆ null       │
# │ 20220227 ┆ 9     ┆ 11         ┆ 15         ┆ ... ┆ null       ┆ null       ┆ null       ┆ null       │
# │ ...      ┆ ...   ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...        ┆ ...        ┆ ...        │
# │ 20221228 ┆ 1584  ┆ 738        ┆ 1861       ┆ ... ┆ null       ┆ null       ┆ null       ┆ null       │
# │ 20221229 ┆ 1593  ┆ 742        ┆ 1869       ┆ ... ┆ null       ┆ null       ┆ null       ┆ null       │
# │ 20221230 ┆ 1593  ┆ 742        ┆ 1869       ┆ ... ┆ null       ┆ null       ┆ null       ┆ null       │
# │ 20221231 ┆ 1600  ┆ 743        ┆ 1872       ┆ ... ┆ null       ┆ null       ┆ null       ┆ null       │
# └──────────┴───────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %%
sorted_cols =list(russia_df[-1].transpose(include_header=True).drop_nulls().with_column(pl.col("column_0").cast(pl.Int32)).sort(by="column_0")["column"])
sorted_cols.insert(0, sorted_cols.pop())

# %%
processed = russia_df.select(sorted_cols,).sort(by="date")

# %%
processed.write_csv("russia.csv",)

# %%
datetime.strptime("20220224","%Y%m%d")
# Out:
# datetime.datetime(2022, 2, 24, 0, 0)

# %%
with open("test.avro",'wb') as fp:
    processed.write_avro(fp)

# %%
with BytesIO() as bt:
    processed.write_avro(bt)
    print(bt.getbuffer().tobytes())

# %%
from typing import Dict
class MyCSV(JsonModel):
    data:bytes

    class Config:
        arbitrary_types_allowed=True
        extra="ignore"
        json_encoders = {
            bytes: lambda v: v.hex()
        }
    
    def __repr__(self) -> str:
        return self.df.__repr__()
    
    @root_validator(pre=True)
    def root(cls, values:Dict):
        if "data" not in values:
            assert "df" in values, "a dataframe should be provided"
            df:pl.DataFrame = values.get("df")
            values["data"] = cls.serialize_df(df)
        elif isinstance(values["data"],str): # Data coming from redis db
            data:str = values.get("data")
            values["data"] = bytes.fromhex(data)
        return values
    
    @staticmethod
    def serialize_df(v:pl.DataFrame)->bytes:
        with BytesIO() as btio:
            v.write_avro(btio)
            return btio.getbuffer().tobytes()
    
    @staticmethod
    def deserialize_df(bt:bytes)->pl.DataFrame:
        with BytesIO() as btio:
            btio.write(bt)
            btio.seek(0)
            return pl.read_avro(btio)
    
    @property
    def df(self)->pl.DataFrame:
        return self.deserialize_df(self.data)

# %%
mycsv = MyCSV(df=processed)
mycsv
# Out:
# shape: (311, 25)
# ┌──────────┬────────────┬──────────┬────────────┬─────┬────────────┬───────┬────────────┬────────────┐
# │ date     ┆ UnmannedCo ┆ NavalShi ┆ AntiAircra ┆ ... ┆ ArmouredFi ┆ Tanks ┆ InfantryFi ┆ TrucksVehi │
# │ ---      ┆ mbatAerial ┆ ps       ┆ ftGuns     ┆     ┆ ghtingVehi ┆ ---   ┆ ghtingVehi ┆ clesandJee │
# │ str      ┆ Vehicles   ┆ ---      ┆ ---        ┆     ┆ cles       ┆ i64   ┆ cles       ┆ ps         │
# │          ┆ ---        ┆ i64      ┆ i64        ┆     ┆ ---        ┆       ┆ ---        ┆ ---        │
# │          ┆ i64        ┆          ┆            ┆     ┆ i64        ┆       ┆ i64        ┆ i64        │
# ╞══════════╪════════════╪══════════╪════════════╪═════╪════════════╪═══════╪════════════╪════════════╡
# │ 20220224 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 5          ┆ 1     ┆ 1          ┆ 9          │
# │ 20220225 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 7          ┆ 2     ┆ 4          ┆ 19         │
# │ 20220226 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 7          ┆ 7     ┆ 11         ┆ 37         │
# │ 20220227 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 11         ┆ 9     ┆ 15         ┆ 66         │
# │ ...      ┆ ...        ┆ ...      ┆ ...        ┆ ... ┆ ...        ┆ ...   ┆ ...        ┆ ...        │
# │ 20221228 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 738        ┆ 1584  ┆ 1861       ┆ 2146       │
# │ 20221229 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 742        ┆ 1593  ┆ 1869       ┆ 2149       │
# │ 20221230 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 742        ┆ 1593  ┆ 1869       ┆ 2149       │
# │ 20221231 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 743        ┆ 1600  ┆ 1872       ┆ 2156       │
# └──────────┴────────────┴──────────┴────────────┴─────┴────────────┴───────┴────────────┴────────────┘

# %%
mycsv.save()
# Out:
# shape: (311, 25)
# ┌──────────┬────────────┬──────────┬────────────┬─────┬────────────┬───────┬────────────┬────────────┐
# │ date     ┆ UnmannedCo ┆ NavalShi ┆ AntiAircra ┆ ... ┆ ArmouredFi ┆ Tanks ┆ InfantryFi ┆ TrucksVehi │
# │ ---      ┆ mbatAerial ┆ ps       ┆ ftGuns     ┆     ┆ ghtingVehi ┆ ---   ┆ ghtingVehi ┆ clesandJee │
# │ str      ┆ Vehicles   ┆ ---      ┆ ---        ┆     ┆ cles       ┆ i64   ┆ cles       ┆ ps         │
# │          ┆ ---        ┆ i64      ┆ i64        ┆     ┆ ---        ┆       ┆ ---        ┆ ---        │
# │          ┆ i64        ┆          ┆            ┆     ┆ i64        ┆       ┆ i64        ┆ i64        │
# ╞══════════╪════════════╪══════════╪════════════╪═════╪════════════╪═══════╪════════════╪════════════╡
# │ 20220224 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 5          ┆ 1     ┆ 1          ┆ 9          │
# │ 20220225 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 7          ┆ 2     ┆ 4          ┆ 19         │
# │ 20220226 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 7          ┆ 7     ┆ 11         ┆ 37         │
# │ 20220227 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 11         ┆ 9     ┆ 15         ┆ 66         │
# │ ...      ┆ ...        ┆ ...      ┆ ...        ┆ ... ┆ ...        ┆ ...   ┆ ...        ┆ ...        │
# │ 20221228 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 738        ┆ 1584  ┆ 1861       ┆ 2146       │
# │ 20221229 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 742        ┆ 1593  ┆ 1869       ┆ 2149       │
# │ 20221230 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 742        ┆ 1593  ┆ 1869       ┆ 2149       │
# │ 20221231 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 743        ┆ 1600  ┆ 1872       ┆ 2156       │
# └──────────┴────────────┴──────────┴────────────┴─────┴────────────┴───────┴────────────┴────────────┘

# %%
from commons.models.dataframe import AvroDF

df = AvroDF(df=processed)
df
# Out:
# shape: (311, 25)
# ┌──────────┬────────────┬──────────┬────────────┬─────┬────────────┬───────┬────────────┬────────────┐
# │ date     ┆ UnmannedCo ┆ NavalShi ┆ AntiAircra ┆ ... ┆ ArmouredFi ┆ Tanks ┆ InfantryFi ┆ TrucksVehi │
# │ ---      ┆ mbatAerial ┆ ps       ┆ ftGuns     ┆     ┆ ghtingVehi ┆ ---   ┆ ghtingVehi ┆ clesandJee │
# │ str      ┆ Vehicles   ┆ ---      ┆ ---        ┆     ┆ cles       ┆ i64   ┆ cles       ┆ ps         │
# │          ┆ ---        ┆ i64      ┆ i64        ┆     ┆ ---        ┆       ┆ ---        ┆ ---        │
# │          ┆ i64        ┆          ┆            ┆     ┆ i64        ┆       ┆ i64        ┆ i64        │
# ╞══════════╪════════════╪══════════╪════════════╪═════╪════════════╪═══════╪════════════╪════════════╡
# │ 20220224 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 5          ┆ 1     ┆ 1          ┆ 9          │
# │ 20220225 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 7          ┆ 2     ┆ 4          ┆ 19         │
# │ 20220226 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 7          ┆ 7     ┆ 11         ┆ 37         │
# │ 20220227 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 11         ┆ 9     ┆ 15         ┆ 66         │
# │ ...      ┆ ...        ┆ ...      ┆ ...        ┆ ... ┆ ...        ┆ ...   ┆ ...        ┆ ...        │
# │ 20221228 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 738        ┆ 1584  ┆ 1861       ┆ 2146       │
# │ 20221229 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 742        ┆ 1593  ┆ 1869       ┆ 2149       │
# │ 20221230 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 742        ┆ 1593  ┆ 1869       ┆ 2149       │
# │ 20221231 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 743        ┆ 1600  ┆ 1872       ┆ 2156       │
# └──────────┴────────────┴──────────┴────────────┴─────┴────────────┴───────┴────────────┴────────────┘

# %%
df.save()
# Out:
# shape: (311, 25)
# ┌──────────┬────────────┬──────────┬────────────┬─────┬────────────┬───────┬────────────┬────────────┐
# │ date     ┆ UnmannedCo ┆ NavalShi ┆ AntiAircra ┆ ... ┆ ArmouredFi ┆ Tanks ┆ InfantryFi ┆ TrucksVehi │
# │ ---      ┆ mbatAerial ┆ ps       ┆ ftGuns     ┆     ┆ ghtingVehi ┆ ---   ┆ ghtingVehi ┆ clesandJee │
# │ str      ┆ Vehicles   ┆ ---      ┆ ---        ┆     ┆ cles       ┆ i64   ┆ cles       ┆ ps         │
# │          ┆ ---        ┆ i64      ┆ i64        ┆     ┆ ---        ┆       ┆ ---        ┆ ---        │
# │          ┆ i64        ┆          ┆            ┆     ┆ i64        ┆       ┆ i64        ┆ i64        │
# ╞══════════╪════════════╪══════════╪════════════╪═════╪════════════╪═══════╪════════════╪════════════╡
# │ 20220224 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 5          ┆ 1     ┆ 1          ┆ 9          │
# │ 20220225 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 7          ┆ 2     ┆ 4          ┆ 19         │
# │ 20220226 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 7          ┆ 7     ┆ 11         ┆ 37         │
# │ 20220227 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 11         ┆ 9     ┆ 15         ┆ 66         │
# │ ...      ┆ ...        ┆ ...      ┆ ...        ┆ ... ┆ ...        ┆ ...   ┆ ...        ┆ ...        │
# │ 20221228 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 738        ┆ 1584  ┆ 1861       ┆ 2146       │
# │ 20221229 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 742        ┆ 1593  ┆ 1869       ┆ 2149       │
# │ 20221230 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 742        ┆ 1593  ┆ 1869       ┆ 2149       │
# │ 20221231 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 743        ┆ 1600  ┆ 1872       ┆ 2156       │
# └──────────┴────────────┴──────────┴────────────┴─────┴────────────┴───────┴────────────┴────────────┘

# %%
AvroDF.get(df.pk)
# Out:
# shape: (311, 25)
# ┌──────────┬────────────┬──────────┬────────────┬─────┬────────────┬───────┬────────────┬────────────┐
# │ date     ┆ UnmannedCo ┆ NavalShi ┆ AntiAircra ┆ ... ┆ ArmouredFi ┆ Tanks ┆ InfantryFi ┆ TrucksVehi │
# │ ---      ┆ mbatAerial ┆ ps       ┆ ftGuns     ┆     ┆ ghtingVehi ┆ ---   ┆ ghtingVehi ┆ clesandJee │
# │ str      ┆ Vehicles   ┆ ---      ┆ ---        ┆     ┆ cles       ┆ i64   ┆ cles       ┆ ps         │
# │          ┆ ---        ┆ i64      ┆ i64        ┆     ┆ ---        ┆       ┆ ---        ┆ ---        │
# │          ┆ i64        ┆          ┆            ┆     ┆ i64        ┆       ┆ i64        ┆ i64        │
# ╞══════════╪════════════╪══════════╪════════════╪═════╪════════════╪═══════╪════════════╪════════════╡
# │ 20220224 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 5          ┆ 1     ┆ 1          ┆ 9          │
# │ 20220225 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 7          ┆ 2     ┆ 4          ┆ 19         │
# │ 20220226 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 7          ┆ 7     ┆ 11         ┆ 37         │
# │ 20220227 ┆ null       ┆ null     ┆ null       ┆ ... ┆ 11         ┆ 9     ┆ 15         ┆ 66         │
# │ ...      ┆ ...        ┆ ...      ┆ ...        ┆ ... ┆ ...        ┆ ...   ┆ ...        ┆ ...        │
# │ 20221228 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 738        ┆ 1584  ┆ 1861       ┆ 2146       │
# │ 20221229 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 742        ┆ 1593  ┆ 1869       ┆ 2149       │
# │ 20221230 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 742        ┆ 1593  ┆ 1869       ┆ 2149       │
# │ 20221231 ┆ 4          ┆ 12       ┆ 16         ┆ ... ┆ 743        ┆ 1600  ┆ 1872       ┆ 2156       │
# └──────────┴────────────┴──────────┴────────────┴─────┴────────────┴───────┴────────────┴────────────┘
